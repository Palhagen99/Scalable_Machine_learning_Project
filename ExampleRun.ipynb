# %%
# !pip install -r requirements.txt
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: hopsworks in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (4.1.4)
# Requirement already satisfied: requests-cache==1.2.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: retry-requests==2.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: torch in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.5.1)
# Requirement already satisfied: tensorflow in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (2.18.0)
# Requirement already satisfied: xgboost==2.0.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (2.0.3)
# Requirement already satisfied: scikit-learn==1.4.1.post1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.4.1.post1)
# Requirement already satisfied: matplotlib==3.8.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (3.8.3)
# Requirement already satisfied: great-expectations==0.17.20 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (0.17.20)
# Requirement already satisfied: pygooglenews in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (0.1.3)
# Requirement already satisfied: transformers in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (4.47.1)
# Requirement already satisfied: attrs>=21.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests-cache==1.2.0->-r requirements.txt (line 5)) (24.3.0)
# Requirement already satisfied: cattrs>=22.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests-cache==1.2.0->-r requirements.txt (line 5)) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests-cache==1.2.0->-r requirements.txt (line 5)) (4.3.6)
# Requirement already satisfied: requests>=2.22 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests-cache==1.2.0->-r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: url-normalize>=1.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests-cache==1.2.0->-r requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests-cache==1.2.0->-r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: numpy in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from xgboost==2.0.3->-r requirements.txt (line 11)) (1.26.4)
# Requirement already satisfied: scipy in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from xgboost==2.0.3->-r requirements.txt (line 11)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from scikit-learn==1.4.1.post1->-r requirements.txt (line 12)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from scikit-learn==1.4.1.post1->-r requirements.txt (line 12)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (4.2.2)
# Requirement already satisfied: Click!=8.1.4,>=7.1.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (8.1.7)
# Requirement already satisfied: colorama>=0.4.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (44.0.0)
# Requirement already satisfied: Ipython>=7.16.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (8.30.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (8.1.5)
# Requirement already satisfied: jinja2>=2.10 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (3.1.4)
# Requirement already satisfied: jsonpatch>=1.22 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (4.23.0)
# Requirement already satisfied: makefun<2,>=1.7.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (1.15.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (3.23.1)
# Requirement already satisfied: mistune>=0.8.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (3.0.2)
# Requirement already satisfied: nbformat>=5.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (5.10.4)
# Requirement already satisfied: notebook>=6.4.10 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (7.3.1)
# Requirement already satisfied: pydantic>=1.9.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (2.10.3)
# Requirement already satisfied: pytz>=2021.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (2024.2)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (0.17.17)
# Requirement already satisfied: tqdm>=4.59.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (4.12.2)
# Requirement already satisfied: tzlocal>=1.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (5.2)
# Requirement already satisfied: pandas>=1.3.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from great-expectations==0.17.20->-r requirements.txt (line 18)) (2.1.4)
# Requirement already satisfied: pyhumps==1.6.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: furl in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: boto3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (1.35.81)
# Requirement already satisfied: pyjks in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (20.0.0)
# Requirement already satisfied: mock in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: avro==1.11.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (1.11.3)
# Requirement already satisfied: sqlalchemy in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (2.0.29)
# Requirement already satisfied: PyMySQL[rsa] in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: fsspec in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (2024.10.0)
# Requirement already satisfied: retrying in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (1.3.4)
# Requirement already satisfied: hopsworks_aiomysql==0.2.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks_aiomysql[sa]==0.2.1->hopsworks->-r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: opensearch-py<=2.4.2,>=1.1.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (2.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.49.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (1.68.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from hopsworks->-r requirements.txt (line 2)) (4.25.5)
# Requirement already satisfied: filelock in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (3.16.1)
# Requirement already satisfied: networkx in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (3.4.2)
# Requirement already satisfied: setuptools in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from sympy==1.13.1->torch->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (3.7.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.11.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pygooglenews->-r requirements.txt (line 19)) (4.12.3)
# Requirement already satisfied: dateparser<2.0.0,>=1.1.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pygooglenews->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: feedparser<7.0.0,>=6.0.8 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pygooglenews->-r requirements.txt (line 19)) (6.0.11)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 20)) (0.27.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 20)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 20)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 20)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 20)) (0.4.5)
# Requirement already satisfied: entrypoints in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from altair<5.0.0,>=4.2.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.4)
# Requirement already satisfied: toolz in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from altair<5.0.0,>=4.2.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 10)) (0.45.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.11.1->pygooglenews->-r requirements.txt (line 19)) (2.6)
# Requirement already satisfied: cffi>=1.12 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from cryptography>=3.2->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.17.1)
# Requirement already satisfied: sgmllib3k in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from feedparser<7.0.0,>=6.0.8->pygooglenews->-r requirements.txt (line 19)) (1.0.0)
# Requirement already satisfied: decorator in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.18.0)
# Requirement already satisfied: stack_data in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipywidgets>=7.5.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipywidgets>=7.5.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipywidgets>=7.5.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jinja2>=2.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonpatch>=1.22->great-expectations==0.17.20->-r requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema>=2.5.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema>=2.5.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema>=2.5.1->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.22.3)
# Requirement already satisfied: rich in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: namex in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 10)) (0.0.8)
# Requirement already satisfied: optree in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 10)) (0.13.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbformat>=5.0->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbformat>=5.0->great-expectations==0.17.20->-r requirements.txt (line 18)) (5.7.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (4.3.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (6.4.2)
# Requirement already satisfied: certifi>=2022.12.07 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks->-r requirements.txt (line 2)) (2024.12.14)
# Requirement already satisfied: tzdata>=2022.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pandas>=1.3.0->great-expectations==0.17.20->-r requirements.txt (line 18)) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pydantic>=1.9.2->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pydantic>=1.9.2->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests>=2.22->requests-cache==1.2.0->-r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from requests>=2.22->requests-cache==1.2.0->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: markdown>=2.6.8 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 10)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: botocore<1.36.0,>=1.35.81 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from boto3->hopsworks->-r requirements.txt (line 2)) (1.35.81)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from boto3->hopsworks->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from boto3->hopsworks->-r requirements.txt (line 2)) (0.10.4)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from furl->hopsworks->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: javaobj-py3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pyjks->hopsworks->-r requirements.txt (line 2)) (0.4.4)
# Requirement already satisfied: pyasn1>=0.3.5 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pyjks->hopsworks->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pyjks->hopsworks->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: pycryptodomex in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pyjks->hopsworks->-r requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: twofish in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pyjks->hopsworks->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: pycparser in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.2->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jedi>=0.16->Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (7.16.4)
# Requirement already satisfied: overrides>=5.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from pexpect>4.3->Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from stack_data->Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from stack_data->Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from stack_data->Ipython>=7.16.3->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.14.0)
# Requirement already satisfied: appnope in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.8.11)
# Requirement already satisfied: nest-asyncio in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: psutil in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.2->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (6.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 10)) (0.1.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.4.0)
# Requirement already satisfied: webencodings in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: fqdn in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (20.11.0)
# Requirement already satisfied: uri-template in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/palhagen/.virtualenvs/Scalable_Machine_learning_Project/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations==0.17.20->-r requirements.txt (line 18)) (2.9.0.20241206)

# %%
#Test of predicting stock price
import ModelForecaster as mf

#Stock to predict. Its sensetiv to how you format the ticker name
#Correctly formatted tickers for OMX30 are: 'ABB.ST', 'ALFA.ST', 'ASSA-B.ST', 'AZN.ST', 'ATCO-A.ST', 'ATCO-B.ST','BOL.ST', 'ELUX-B.ST', 'ERIC-B.ST', 'ESSITY-B.ST', 'EVO.ST', 'GETI-B.ST', 'HM-B.ST', 'HEXA-B.ST', 'INVE-B.ST', 'KINV-B.ST', 'NDA-SE.ST', 'SAND.ST', 'SINCH.ST', 'SEB-A.ST', 'SKA-B.ST', 'SKF-B.ST', 'SCA-B.ST', 'SHB-A.ST', 'SWED-A.ST', 'TEL2-B.ST', 'TELIA.ST', 'VOLV-B.ST'

stock_ticker = "ABB.ST"

prediction, prev_closing = mf.forecast_stock_price(stock_ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Device set to use mps:0
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x31d516a20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step

# %%
#Plot the close price and then at the end of then plot the prediction in a different color
import matplotlib.pyplot as plt
import numpy as np

plt.plot(prev_closing, label='Previous Closing Prices', linestyle='--',)

# Create an array of indices for the predicted values, right after the last index of prev_closing
predicted_indices = np.arange(len(prev_closing), len(prev_closing) + len(prediction))

# Plot the predicted closing prices in red, using the correct indices
plt.plot(predicted_indices, prediction, color='red', label='Predicted Prices',linestyle='--',)

# Adding labels and a legend
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Stock Prices with Predictions')
plt.legend()

print(prediction)
# Out:
# [599.8602  600.7451  601.51025 602.1955  601.18243]
